# %%
from utils import *

# %%
import scipy.io

# 1. 파일 불러오기
file_path = 'PA_models_Matlab_code/P_TX_Case1.mat'  # 가지고 계신 파일 경로로 변경하세요.
mat_data = scipy.io.loadmat(file_path)

# 2. 데이터 타입 확인
print(type(mat_data))  # <class 'dict'> 가 출력됩니다.

# 3. 파일 내 변수(키) 확인하기
print(mat_data.keys())

# 'my_array'라는 이름으로 저장된 데이터가 있다고 가정할 때
my_actual_data = mat_data['P_tx']
print(my_actual_data.shape) # 데이터의 형태(크기) 확인
print(my_actual_data)       # 데이터 내용 확인

# %%
print(mat_data)

# %%
mat_data = scipy.io.loadmat('PA_models_Matlab_code/PA_memory_models.mat')
print(mat_data.keys())
print(mat_data['parameters'].shape)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'parameters'])
# (100, 1)
